# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
from seaborn import load_dataset
import pandas as pd

df = load_dataset('mpg')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df[['acceleration', 'horsepower']]
# Out:
#      acceleration  horsepower
# 0            12.0       130.0
# 1            11.5       165.0
# 2            11.0       150.0
# 3            12.0       150.0
# 4            10.5       140.0
# ..            ...         ...
# 393          15.6        86.0
# 394          24.6        52.0
# 395          11.6        84.0
# 396          18.6        79.0
# 397          19.4        82.0
#
# [398 rows x 2 columns]

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

#df = pd.read_csv('https://plotly.github.io/datasets/country_indicators.csv')

available_indicators = df.columns

app.layout = html.Div([
    html.Div([

        html.Div([
            dcc.Dropdown(
                id='xaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                value='acceleration'
            ),
            dcc.RadioItems(
                id='xaxis-type',
                options=[{'label': i, 'value': i} for i in ['Linear', 'Log']],
                value='Linear',
                labelStyle={'display': 'inline-block'}
            )
        ],
        style={'width': '48%', 'display': 'inline-block'}),

        html.Div([
            dcc.Dropdown(
                id='yaxis-column',
                options=[{'label': i, 'value': i} for i in available_indicators],
                value='mpg'
            ),
            dcc.RadioItems(
                id='yaxis-type',
                options=[{'label': i, 'value': i} for i in ['Linear', 'Log']],
                value='Linear',
                labelStyle={'display': 'inline-block'}
            )
        ],style={'width': '48%', 'float': 'right', 'display': 'inline-block'})
    ]),

    dcc.Graph(id='indicator-graphic'),

    dcc.Slider(
        id='year--slider',
        min=df['model_year'].min(),
        max=df['model_year'].max(),
        value=df['model_year'].max(),
        marks={str(year): str(year) for year in df['model_year'].unique()},
        step=None
    )
])

@app.callback(
    Output('indicator-graphic', 'figure'),
    Input('xaxis-column', 'value'),
    Input('yaxis-column', 'value'),
    Input('xaxis-type', 'value'),
    Input('yaxis-type', 'value'),
    Input('year--slider', 'value'))
def update_graph(xaxis_column_name, yaxis_column_name,
                 xaxis_type, yaxis_type,
                 year_value):
    dff = df[df['model_year'] == year_value]

    fig = px.scatter(x=dff[xaxis_column_name],
                     y=dff[yaxis_column_name],
                     size=dff.acceleration, color=dff.horsepower)
                     #hover_name=dff[yaxis_column_name]['origin'])

    fig.update_layout(margin={'l': 40, 'b': 40, 't': 10, 'r': 0}, hovermode='closest')

    fig.update_xaxes(title=xaxis_column_name,
                     type='linear' if xaxis_type == 'Linear' else 'log')

    fig.update_yaxes(title=yaxis_column_name,
                     type='linear' if yaxis_type == 'Linear' else 'log')

    return fig

# %%
if __name__ == '__main__':
    app.run_server(port = 3050)
# Out:
# Dash is running on http://127.0.0.1:3050/
#
# Dash is running on http://127.0.0.1:3050/
#
# Dash is running on http://127.0.0.1:3050/
#
# Dash is running on http://127.0.0.1:3050/
#
# Dash is running on http://127.0.0.1:3050/
#
# Dash is running on http://127.0.0.1:3050/
#
# Dash is running on http://127.0.0.1:3050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:3050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [27/Dec/2020 15:16:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Dec/2020 15:16:02] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Dec/2020 15:16:02] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Dec/2020 15:16:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Dec/2020 15:16:22] "POST /_dash-update-component HTTP/1.1" 200 -
# ...
